# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.max_columns=50

# %%
df = pd.read_csv('C:\\Users\\DELL\\Downloads\\archive\\Credit card transactions - India - Simple.csv')
df
# Out:
#        index                   City       Date  Card Type Exp Type Gender  \
# 0          0           Delhi, India  29-Oct-14       Gold    Bills      F
# 1          1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F
# 2          2       Bengaluru, India  27-Aug-14     Silver    Bills      F
# 3          3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F
# 4          4       Bengaluru, India   5-May-15       Gold    Bills      F
# ...      ...                    ...        ...        ...      ...    ...
# 26047  26047         Kolkata, India  22-Jun-14     Silver   Travel      F
# 26048  26048            Pune, India   3-Aug-14  Signature   Travel      M
# 26049  26049       Hyderabad, India  16-Jan-15     Silver   Travel      M
# 26050  26050          Kanpur, India  14-Sep-14     Silver   Travel      M
# 26051  26051       Hyderabad, India  19-Oct-13  Signature    Bills      M
#
#        Amount
# 0       82475
# 1       32555
# 2      101738
# 3      123424
# ...

# %%
df.shape
# Out:
# (26052, 7)

# %%
df.columns
# Out:
# Index(['index', 'City', 'Date', 'Card Type', 'Exp Type', 'Gender', 'Amount'], dtype='object')

# %%
df.columns=['S.No','City','Date','CardType','Expenditure Type','Gender','Amount']
df
# Out:
#         S.No                   City       Date   CardType Expenditure Type  \
# 0          0           Delhi, India  29-Oct-14       Gold            Bills
# 1          1  Greater Mumbai, India  22-Aug-14   Platinum            Bills
# 2          2       Bengaluru, India  27-Aug-14     Silver            Bills
# 3          3  Greater Mumbai, India  12-Apr-14  Signature            Bills
# 4          4       Bengaluru, India   5-May-15       Gold            Bills
# ...      ...                    ...        ...        ...              ...
# 26047  26047         Kolkata, India  22-Jun-14     Silver           Travel
# 26048  26048            Pune, India   3-Aug-14  Signature           Travel
# 26049  26049       Hyderabad, India  16-Jan-15     Silver           Travel
# 26050  26050          Kanpur, India  14-Sep-14     Silver           Travel
# 26051  26051       Hyderabad, India  19-Oct-13  Signature            Bills
#
#       Gender  Amount
# 0          F   82475
# 1          F   32555
# ...

# %%
df.columns
# Out:
# Index(['S.No', 'City', 'Date', 'CardType', 'Expenditure Type', 'Gender',
#        'Amount'],
#       dtype='object')

# %%
df.head()
# Out:
#    S.No                   City       Date   CardType Expenditure Type Gender  \
# 0     0           Delhi, India  29-Oct-14       Gold            Bills      F
# 1     1  Greater Mumbai, India  22-Aug-14   Platinum            Bills      F
# 2     2       Bengaluru, India  27-Aug-14     Silver            Bills      F
# 3     3  Greater Mumbai, India  12-Apr-14  Signature            Bills      F
# 4     4       Bengaluru, India   5-May-15       Gold            Bills      F
#
#    Amount
# 0   82475
# 1   32555
# 2  101738
# 3  123424
# 4  171574

# %%
df.tail()
# Out:
#         S.No              City       Date   CardType Expenditure Type Gender  \
# 26047  26047    Kolkata, India  22-Jun-14     Silver           Travel      F
# 26048  26048       Pune, India   3-Aug-14  Signature           Travel      M
# 26049  26049  Hyderabad, India  16-Jan-15     Silver           Travel      M
# 26050  26050     Kanpur, India  14-Sep-14     Silver           Travel      M
# 26051  26051  Hyderabad, India  19-Oct-13  Signature            Bills      M
#
#        Amount
# 26047  128191
# 26048  246316
# 26049  265019
# 26050   88174
# 26051  184410

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26052 entries, 0 to 26051
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   S.No              26052 non-null  int64
#  1   City              26052 non-null  object
#  2   Date              26052 non-null  object
#  3   CardType          26052 non-null  object
#  4   Expenditure Type  26052 non-null  object
#  5   Gender            26052 non-null  object
#  6   Amount            26052 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 1.4+ MB

# %%
df['Gender'].value_counts()
# Out:
# F    13680
# M    12372
# Name: Gender, dtype: int64

# %%
df['CardType'].value_counts()
# Out:
# Silver       6840
# Signature    6447
# Platinum     6398
# Gold         6367
# Name: CardType, dtype: int64

# %%
df['Expenditure Type'].value_counts()
# Out:
# Food             5463
# Fuel             5257
# Bills            5078
# Entertainment    4762
# Grocery          4754
# Travel            738
# Name: Expenditure Type, dtype: int64

# %%
df['City'].value_counts()
# Out:
# Bengaluru, India          3552
# Greater Mumbai, India     3493
# Ahmedabad, India          3491
# Delhi, India              3482
# Hyderabad, India           784
#                           ...
# Rayagada, India              1
# Varanasi, India              1
# Hugli-Chinsurah, India       1
# Alirajpur, India             1
# Fazilka, India               1
# Name: City, Length: 986, dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
df.isnull()
# Out:
#         S.No   City   Date  CardType  Expenditure Type  Gender  Amount
# 0      False  False  False     False             False   False   False
# 1      False  False  False     False             False   False   False
# 2      False  False  False     False             False   False   False
# 3      False  False  False     False             False   False   False
# 4      False  False  False     False             False   False   False
# ...      ...    ...    ...       ...               ...     ...     ...
# 26047  False  False  False     False             False   False   False
# 26048  False  False  False     False             False   False   False
# 26049  False  False  False     False             False   False   False
# 26050  False  False  False     False             False   False   False
# 26051  False  False  False     False             False   False   False
#
# [26052 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# S.No                0
# City                0
# Date                0
# CardType            0
# Expenditure Type    0
# Gender              0
# Amount              0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [S.No, City, Date, CardType, Expenditure Type, Gender, Amount]
# Index: []

# %%
df.notnull()
# Out:
#        S.No  City  Date  CardType  Expenditure Type  Gender  Amount
# 0      True  True  True      True              True    True    True
# 1      True  True  True      True              True    True    True
# 2      True  True  True      True              True    True    True
# 3      True  True  True      True              True    True    True
# 4      True  True  True      True              True    True    True
# ...     ...   ...   ...       ...               ...     ...     ...
# 26047  True  True  True      True              True    True    True
# 26048  True  True  True      True              True    True    True
# 26049  True  True  True      True              True    True    True
# 26050  True  True  True      True              True    True    True
# 26051  True  True  True      True              True    True    True
#
# [26052 rows x 7 columns]

# %%
df.notnull().sum()
# Out:
# S.No                26052
# City                26052
# Date                26052
# CardType            26052
# Expenditure Type    26052
# Gender              26052
# Amount              26052
# dtype: int64

# %%
df.dropna()
# Out:
#         S.No                   City       Date   CardType Expenditure Type  \
# 0          0           Delhi, India  29-Oct-14       Gold            Bills
# 1          1  Greater Mumbai, India  22-Aug-14   Platinum            Bills
# 2          2       Bengaluru, India  27-Aug-14     Silver            Bills
# 3          3  Greater Mumbai, India  12-Apr-14  Signature            Bills
# 4          4       Bengaluru, India   5-May-15       Gold            Bills
# ...      ...                    ...        ...        ...              ...
# 26047  26047         Kolkata, India  22-Jun-14     Silver           Travel
# 26048  26048            Pune, India   3-Aug-14  Signature           Travel
# 26049  26049       Hyderabad, India  16-Jan-15     Silver           Travel
# 26050  26050          Kanpur, India  14-Sep-14     Silver           Travel
# 26051  26051       Hyderabad, India  19-Oct-13  Signature            Bills
#
#       Gender  Amount
# 0          F   82475
# 1          F   32555
# ...

# %%
df.fillna('missing_value',inplace=True)
df
# Out:
#         S.No                   City       Date   CardType Expenditure Type  \
# 0          0           Delhi, India  29-Oct-14       Gold            Bills
# 1          1  Greater Mumbai, India  22-Aug-14   Platinum            Bills
# 2          2       Bengaluru, India  27-Aug-14     Silver            Bills
# 3          3  Greater Mumbai, India  12-Apr-14  Signature            Bills
# 4          4       Bengaluru, India   5-May-15       Gold            Bills
# ...      ...                    ...        ...        ...              ...
# 26047  26047         Kolkata, India  22-Jun-14     Silver           Travel
# 26048  26048            Pune, India   3-Aug-14  Signature           Travel
# 26049  26049       Hyderabad, India  16-Jan-15     Silver           Travel
# 26050  26050          Kanpur, India  14-Sep-14     Silver           Travel
# 26051  26051       Hyderabad, India  19-Oct-13  Signature            Bills
#
#       Gender  Amount
# 0          F   82475
# 1          F   32555
# ...

# %%
df['Gender'].replace(to_replace='M',value='Male',inplace=True)
df
# Out:
#         S.No                   City       Date   CardType Expenditure Type  \
# 0          0           Delhi, India  29-Oct-14       Gold            Bills
# 1          1  Greater Mumbai, India  22-Aug-14   Platinum            Bills
# 2          2       Bengaluru, India  27-Aug-14     Silver            Bills
# 3          3  Greater Mumbai, India  12-Apr-14  Signature            Bills
# 4          4       Bengaluru, India   5-May-15       Gold            Bills
# ...      ...                    ...        ...        ...              ...
# 26047  26047         Kolkata, India  22-Jun-14     Silver           Travel
# 26048  26048            Pune, India   3-Aug-14  Signature           Travel
# 26049  26049       Hyderabad, India  16-Jan-15     Silver           Travel
# 26050  26050          Kanpur, India  14-Sep-14     Silver           Travel
# 26051  26051       Hyderabad, India  19-Oct-13  Signature            Bills
#
#       Gender  Amount
# 0          F   82475
# 1          F   32555
# ...

# %%
df['Gender'].replace(to_replace='F',value='Female',inplace=True)
df
# Out:
#         S.No                   City       Date   CardType Expenditure Type  \
# 0          0           Delhi, India  29-Oct-14       Gold            Bills
# 1          1  Greater Mumbai, India  22-Aug-14   Platinum            Bills
# 2          2       Bengaluru, India  27-Aug-14     Silver            Bills
# 3          3  Greater Mumbai, India  12-Apr-14  Signature            Bills
# 4          4       Bengaluru, India   5-May-15       Gold            Bills
# ...      ...                    ...        ...        ...              ...
# 26047  26047         Kolkata, India  22-Jun-14     Silver           Travel
# 26048  26048            Pune, India   3-Aug-14  Signature           Travel
# 26049  26049       Hyderabad, India  16-Jan-15     Silver           Travel
# 26050  26050          Kanpur, India  14-Sep-14     Silver           Travel
# 26051  26051       Hyderabad, India  19-Oct-13  Signature            Bills
#
#        Gender  Amount
# 0      Female   82475
# ...

# %% [markdown]
# # Sorting

# %%
df1=df.sort_values(by='CardType',ascending=True)
df1
# Out:
#         S.No                   City       Date CardType Expenditure Type  \
# 0          0           Delhi, India  29-Oct-14     Gold            Bills
# 18001  18001          Khanna, India  17-Feb-15     Gold             Fuel
# 18000  18000      Mahemdabad, India  24-Aug-14     Gold             Fuel
# 22136  22136          Jaipur, India   2-Dec-13     Gold             Fuel
# 11573  11573  Greater Mumbai, India  15-Dec-13     Gold    Entertainment
# ...      ...                    ...        ...      ...              ...
# 7224    7224           Delhi, India   6-Feb-14   Silver             Fuel
# 21002  21002          Kanpur, India  11-Dec-13   Silver          Grocery
# 21001  21001         Kolkata, India   3-Nov-14   Silver          Grocery
# 21031  21031       Hyderabad, India   4-Feb-14   Silver             Food
# 20773  20773         Chennai, India   5-May-15   Silver             Food
#
#        Gender  Amount
# 0      Female   82475
# 18001    Male  131681
# ...

# %%
df2=df.sort_values(by='Gender',ascending=True)
df2
# Out:
#         S.No                   City       Date   CardType Expenditure Type  \
# 0          0           Delhi, India  29-Oct-14       Gold            Bills
# 11002  11002       Bengaluru, India  28-Jan-14   Platinum             Food
# 11003  11003           Delhi, India  24-Dec-14       Gold          Grocery
# 11006  11006  Greater Mumbai, India  24-Dec-14   Platinum    Entertainment
# 21217  21217         Chennai, India  26-Feb-14     Silver             Food
# ...      ...                    ...        ...        ...              ...
# 12395  12395  Greater Mumbai, India  27-Dec-13   Platinum             Food
# 12398  12398       Ahmedabad, India  26-Jul-14  Signature             Food
# 12399  12399           Delhi, India  28-Nov-14   Platinum          Grocery
# 12461  12461           Delhi, India  10-Jun-14       Gold          Grocery
# 26051  26051       Hyderabad, India  19-Oct-13  Signature            Bills
#
#        Gender  Amount
# 0      Female   82475
# ...

# %%
df3=df.sort_values(by='Expenditure Type',ascending=True)
df3
# Out:
#         S.No              City       Date   CardType Expenditure Type  Gender  \
# 0          0      Delhi, India  29-Oct-14       Gold            Bills  Female
# 11224  11224  Ahmedabad, India  24-Jul-14   Platinum            Bills    Male
# 11222  11222  Bengaluru, India  14-Jun-14       Gold            Bills  Female
# 11212  11212  Ahmedabad, India  12-Sep-14       Gold            Bills  Female
# 11209  11209  Ahmedabad, India   5-Dec-14     Silver            Bills  Female
# ...      ...               ...        ...        ...              ...     ...
# 25561  25561    Lucknow, India  26-Mar-15     Silver           Travel  Female
# 25562  25562  Hyderabad, India  13-Feb-15   Platinum           Travel    Male
# 25563  25563      Surat, India   8-Dec-14   Platinum           Travel    Male
# 25554  25554     Jaipur, India   5-Apr-14  Signature           Travel  Female
# 25495  25495    Lucknow, India  29-Jun-14       Gold           Travel    Male
#
#        Amount
# 0       82475
# ...

# %% [markdown]
# # Grouping

# %%
expense_type = df.groupby('Expenditure Type')['Amount'].sum()
print("\nTotal Amount Spent by Expense Type:")
print(expense_type)
# Out:
# Total Amount Spent by Expense Type:
# Expenditure Type
# Bills            907072473
# Entertainment    726437536
# Food             824724009
# Fuel             789135821
# Grocery          718207923
# Travel           109255611
# Name: Amount, dtype: int64

# %%
gender = df.groupby('Gender')['Amount'].sum()
print("\nTotal Amount Spent by Gender:")
print(gender)
# Out:
# Total Amount Spent by Gender:
# Gender
# Female    2205311030
# Male      1869522343
# Name: Amount, dtype: int64

# %%
city = df.groupby('City')['Amount'].sum()
print("\nTotal Amount Spent in each City:")
print(city)
# Out:
# Total Amount Spent in each City:
# City
# Achalpur, India     1606641
# Adilabad, India     1769464
# Adityapur, India     963993
# Adoni, India        1575355
# Adoor, India         647725
#                      ...
# Zaidpur, India       723818
# Zamania, India       865634
# Zira, India         1640547
# Zirakpur, India      549663
# Zunheboto, India     466429
# Name: Amount, Length: 986, dtype: int64

# %% [markdown]
# # Stastical Functions

# %%
df['Amount'].max()
# Out:
# 998077

# %%
df['Amount'].min()
# Out:
# 1005

# %%
df[df["Amount"]==df["Amount"].max()]
# Out:
#     S.No                   City       Date  CardType Expenditure Type  Gender  \
# 80    80  Greater Mumbai, India  14-Oct-14  Platinum            Bills  Female
#
#     Amount
# 80  998077

# %%
df[df["Amount"]==df["Amount"].min()]
# Out:
#         S.No          City      Date  CardType Expenditure Type  Gender  \
# 13444  13444  Delhi, India  2-May-14  Platinum          Grocery  Female
#
#        Amount
# 13444    1005

# %%
df['Amount'].mean()
# Out:
# 156411.5374251497

# %%
df['Amount'].std()
# Out:
# 103063.25428673111

# %%
df['Amount'].var()
# Out:
# 10622034384.1714

# %% [markdown]
# # Data Visuilization

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
card_type_counts = df['CardType'].value_counts()
plt.figure(figsize=(8, 6))
plt.bar(card_type_counts.index, card_type_counts.values)
plt.xlabel('CardType')
plt.ylabel('Count')
plt.title('Distribution of Card Types')
plt.xticks(rotation=45)
plt.show()

# %%
ct = pd.crosstab(df['CardType'], df['Gender'])

plt.figure(figsize=(10, 8))
ax = ct.plot(kind='bar', stacked=True, edgecolor='k')

# Add the count values on top of each segment of the bars
for i in ax.patches:
    ax.text(i.get_x() + i.get_width() / 2, i.get_y() + i.get_height() / 2, str(i.get_height()), 
            fontsize=10, color='white', ha='center', va='center')

plt.xlabel('CardType')
plt.ylabel('Count')
plt.title('Card Types by Gender')
plt.xticks(rotation=45)
plt.legend(title='Gender', loc='upper right')
plt.show()

# %%
expense_type_counts = df['Expenditure Type'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(expense_type_counts.values, labels=expense_type_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Proportion of Expenditure Types')
plt.show()

# %%
daily_spending = df.groupby('Date')['Amount'].sum()

plt.figure(figsize=(10, 6))
plt.plot(daily_spending.index, daily_spending.values)
plt.xlabel('Date')
plt.ylabel('Total Amount Spent')
plt.title('Daily Total Amount Spent Over Time')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
pivot_df = df.pivot_table(index='Date', columns='Expenditure Type', values='Amount', aggfunc='sum', fill_value=0)

plt.figure(figsize=(10, 6))
plt.stackplot(pivot_df.index, pivot_df.values.T, labels=pivot_df.columns)
plt.xlabel('Date')
plt.ylabel('Total Amount')
plt.title('Stacked Area Chart of Expense Types over Time')
plt.xticks(rotation=30)
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Q1. Which card type is most popular. Represent through piechart

# %%
plt.figure(figsize=(6,6))
l=["Silver","Signature","Platinum","Gold"]
plt.pie(m_card,labels=l,shadow=True,autopct="%0.0f%%",textprops={'fontsize': 20},wedgeprops={"width":0.8})
plt.show()

# %% [markdown]
# Answer: Silver card type is the most popular.

# %% [markdown]
# # Q2. Which expense type is most popular. Represent through graph

# %%
plt.figure(figsize=(8,6))
sns.countplot(x ="Expenditure Type",data=df,edgecolor="white")
plt.show()

# %% [markdown]
# Answer: Food Expense type is the most popular

# %% [markdown]
# # Q3. Which gender spend more in Credit Card? Show through piechart.

# %%
plt.figure(figsize=(6,6))
gen = ["Female","Male"]
plt.pie(m_gen,labels=gen,shadow=True,autopct="%0.0f%%",textprops={"fontsize":10},colors=["pink","blue"],wedgeprops={'width': 0.5})
plt.show()

# %% [markdown]
# Answer: Female spends more in credit cards.

# %% [markdown]
# # Q4.Find top 5 cities of India which all spended credit card maximum

# %%
max_city = pd.DataFrame(df['City'].value_counts())[0:5]
max_city
# Out:
#                        City
# Bengaluru, India       3552
# Greater Mumbai, India  3493
# Ahmedabad, India       3491
# Delhi, India           3482
# Hyderabad, India        784

# %% [markdown]
# # Q5.Which card type were mostly used by the Males and Females?

# %%
card_gen = pd.DataFrame(df.groupby('Gender')['CardType'].value_counts())
card_gen
# Out:
#                   CardType
# Gender CardType
# Female Silver         3773
#        Signature      3368
#        Gold           3287
#        Platinum       3252
# Male   Platinum       3146
#        Gold           3080
#        Signature      3079
#        Silver         3067

# %% [markdown]
# # Q6. Represent the comparison through graph.

# %%
plt.figure(figsize=(8,6))
sns.countplot(x="CardType",hue="Gender",data=df,palette=["pink","purple"],edgecolor="black")
plt.show()

# %% [markdown]
# Answer: Females used the Silver card type where as Males have used the platinum card types more

# %% [markdown]
# # Q7. What is the average credit card spending per person in each city?

# %%
city_spending = df.groupby('City')['Amount'].mean()

print(city_spending)
# Out:
# City
# Achalpur, India     178515.666667
# Adilabad, India     176946.400000
# Adityapur, India    160665.500000
# Adoni, India        175039.444444
# Adoor, India         92532.142857
#                         ...
# Zaidpur, India      144763.600000
# Zamania, India      144272.333333
# Zira, India         182283.000000
# Zirakpur, India     183221.000000
# Zunheboto, India    155476.333333
# Name: Amount, Length: 986, dtype: float64
